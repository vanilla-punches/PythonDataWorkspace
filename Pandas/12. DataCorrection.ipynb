# %% [markdown]
# # Data Correction

# %%
import pandas as pd
df = pd.read_excel('score.xlsx', index_col='Application Number')
df
# Out:
#                      Name School  Height  English  Math  Biology  Finance  \
# Application Number
# #1                    Ian     A1     178       90   100       88       95
# #2                  Jason     A2     198      100    82       78       88
# #3                  Smith     A2     168       85    87       90       75
# #4                   John     A1     188       70    65       95       92
# #5                   Kara     A1     201       82    78       88       84
# #6                  Daisy     A1     172       91    80       76       80
# #7                   Jack     A2     174       77    50       85      100
# #8                  Poppy     A1     180       80    90       70       89
#
#                     Coding
# Application Number
# #1                  Python
# #2                     NaN
# #3                     C++
# #4                    Java
# #5                     NaN
# #6                     NaN
# #7                       R
# #8                  Python

# %% [markdown]
# ## Column correction

# %%
df['School'].replace({'A1':'Columbia', 'A2':'New York'})
# Out:
# Application Number
# #1    Columbia
# #2    New York
# #3    New York
# #4    Columbia
# #5    Columbia
# #6    Columbia
# #7    New York
# #8    Columbia
# Name: School, dtype: object

# %%
df
# Out:
#                      Name School  Height  English  Math  Biology  Finance  \
# Application Number
# #1                    Ian     A1     178       90   100       88       95
# #2                  Jason     A2     198      100    82       78       88
# #3                  Smith     A2     168       85    87       90       75
# #4                   John     A1     188       70    65       95       92
# #5                   Kara     A1     201       82    78       88       84
# #6                  Daisy     A1     172       91    80       76       80
# #7                   Jack     A2     174       77    50       85      100
# #8                  Poppy     A1     180       80    90       70       89
#
#                     Coding
# Application Number
# #1                  Python
# #2                     NaN
# #3                     C++
# #4                    Java
# #5                     NaN
# #6                     NaN
# #7                       R
# #8                  Python

# %%
df['School'].replace({'A1':'Columbia', 'A2':'New York'}, inplace=True)
df
# Out:
#                      Name    School  Height  English  Math  Biology  Finance  \
# Application Number
# #1                    Ian  Columbia     178       90   100       88       95
# #2                  Jason  New York     198      100    82       78       88
# #3                  Smith  New York     168       85    87       90       75
# #4                   John  Columbia     188       70    65       95       92
# #5                   Kara  Columbia     201       82    78       88       84
# #6                  Daisy  Columbia     172       91    80       76       80
# #7                   Jack  New York     174       77    50       85      100
# #8                  Poppy  Columbia     180       80    90       70       89
#
#                     Coding
# Application Number
# #1                  Python
# #2                     NaN
# #3                     C++
# #4                    Java
# #5                     NaN
# #6                     NaN
# #7                       R
# ...

# %%
df['Coding'].str.lower()
# Out:
# Application Number
# #1    python
# #2       NaN
# #3       c++
# #4      java
# #5       NaN
# #6       NaN
# #7         r
# #8    python
# Name: Coding, dtype: object

# %%
df['Coding'] = df['Coding'].str.lower()
df
# Out:
#                      Name    School  Height  English  Math  Biology  Finance  \
# Application Number
# #1                    Ian  Columbia     178       90   100       88       95
# #2                  Jason  New York     198      100    82       78       88
# #3                  Smith  New York     168       85    87       90       75
# #4                   John  Columbia     188       70    65       95       92
# #5                   Kara  Columbia     201       82    78       88       84
# #6                  Daisy  Columbia     172       91    80       76       80
# #7                   Jack  New York     174       77    50       85      100
# #8                  Poppy  Columbia     180       80    90       70       89
#
#                     Coding
# Application Number
# #1                  python
# #2                     NaN
# #3                     c++
# #4                    java
# #5                     NaN
# #6                     NaN
# #7                       r
# ...

# %%
df['School'] = df['School'] + ' University' # Adding name
df
# Out:
#                      Name               School  Height  English  Math  \
# Application Number
# #1                    Ian  Columbia University     178       90   100
# #2                  Jason  New York University     198      100    82
# #3                  Smith  New York University     168       85    87
# #4                   John  Columbia University     188       70    65
# #5                   Kara  Columbia University     201       82    78
# #6                  Daisy  Columbia University     172       91    80
# #7                   Jack  New York University     174       77    50
# #8                  Poppy  Columbia University     180       80    90
#
#                     Biology  Finance  Coding
# Application Number
# #1                       88       95  python
# #2                       78       88     NaN
# #3                       90       75     c++
# #4                       95       92    java
# #5                       88       84     NaN
# ...

# %% [markdown]
# ## Adding another columns

# %%
df['Total'] = df['English'] + df['Math'] + df['Biology'] + df['Finance']
df
# Out:
#                      Name               School  Height  English  Math  \
# Application Number
# #1                    Ian  Columbia University     178       90   100
# #2                  Jason  New York University     198      100    82
# #3                  Smith  New York University     168       85    87
# #4                   John  Columbia University     188       70    65
# #5                   Kara  Columbia University     201       82    78
# #6                  Daisy  Columbia University     172       91    80
# #7                   Jack  New York University     174       77    50
# #8                  Poppy  Columbia University     180       80    90
#
#                     Biology  Finance  Coding  Total
# Application Number
# #1                       88       95  python    373
# #2                       78       88     NaN    348
# #3                       90       75     c++    337
# #4                       95       92    java    322
# ...

# %%
df['Result'] = 'Fail'
df
# Out:
#                      Name               School  Height  English  Math  \
# Application Number
# #1                    Ian  Columbia University     178       90   100
# #2                  Jason  New York University     198      100    82
# #3                  Smith  New York University     168       85    87
# #4                   John  Columbia University     188       70    65
# #5                   Kara  Columbia University     201       82    78
# #6                  Daisy  Columbia University     172       91    80
# #7                   Jack  New York University     174       77    50
# #8                  Poppy  Columbia University     180       80    90
#
#                     Biology  Finance  Coding  Total Result
# Application Number
# #1                       88       95  python    373   Fail
# #2                       78       88     NaN    348   Fail
# #3                       90       75     c++    337   Fail
# #4                       95       92    java    322   Fail
# ...

# %%
df.loc[df['Total'] > 330, 'Result'] = 'Pass'
df
# Out:
#                      Name               School  Height  English  Math  \
# Application Number
# #1                    Ian  Columbia University     178       90   100
# #2                  Jason  New York University     198      100    82
# #3                  Smith  New York University     168       85    87
# #4                   John  Columbia University     188       70    65
# #5                   Kara  Columbia University     201       82    78
# #6                  Daisy  Columbia University     172       91    80
# #7                   Jack  New York University     174       77    50
# #8                  Poppy  Columbia University     180       80    90
#
#                     Biology  Finance  Coding  Total Result
# Application Number
# #1                       88       95  python    373   Pass
# #2                       78       88     NaN    348   Pass
# #3                       90       75     c++    337   Pass
# #4                       95       92    java    322   Fail
# ...

# %% [markdown]
# ## Removing columns

# %%
df.drop(columns=['Total'])
# Out:
#                      Name               School  Height  English  Math  \
# Application Number
# #1                    Ian  Columbia University     178       90   100
# #2                  Jason  New York University     198      100    82
# #3                  Smith  New York University     168       85    87
# #4                   John  Columbia University     188       70    65
# #5                   Kara  Columbia University     201       82    78
# #6                  Daisy  Columbia University     172       91    80
# #7                   Jack  New York University     174       77    50
# #8                  Poppy  Columbia University     180       80    90
#
#                     Biology  Finance  Coding Result
# Application Number
# #1                       88       95  python   Pass
# #2                       78       88     NaN   Pass
# #3                       90       75     c++   Pass
# #4                       95       92    java   Fail
# ...

# %%
df.drop(columns=['English', 'Coding', 'Total'])
# Out:
#                      Name               School  Height  Math  Biology  \
# Application Number
# #1                    Ian  Columbia University     178   100       88
# #2                  Jason  New York University     198    82       78
# #3                  Smith  New York University     168    87       90
# #4                   John  Columbia University     188    65       95
# #5                   Kara  Columbia University     201    78       88
# #6                  Daisy  Columbia University     172    80       76
# #7                   Jack  New York University     174    50       85
# #8                  Poppy  Columbia University     180    90       70
#
#                     Finance Result
# Application Number
# #1                       95   Pass
# #2                       88   Pass
# #3                       75   Pass
# #4                       92   Fail
# #5                       84   Pass
# #6                       80   Fail
# #7                      100   Fail
# ...

# %% [markdown]
# ## Removing rows

# %%
df.drop(index='#4')
# Out:
#                      Name               School  Height  English  Math  \
# Application Number
# #1                    Ian  Columbia University     178       90   100
# #2                  Jason  New York University     198      100    82
# #3                  Smith  New York University     168       85    87
# #5                   Kara  Columbia University     201       82    78
# #6                  Daisy  Columbia University     172       91    80
# #7                   Jack  New York University     174       77    50
# #8                  Poppy  Columbia University     180       80    90
#
#                     Biology  Finance  Coding  Total Result
# Application Number
# #1                       88       95  python    373   Pass
# #2                       78       88     NaN    348   Pass
# #3                       90       75     c++    337   Pass
# #5                       88       84     NaN    332   Pass
# #6                       76       80     NaN    327   Fail
# ...

# %%
filt = df['Math'] < 90
df[filt]
# Out:
#                      Name               School  Height  English  Math  \
# Application Number
# #2                  Jason  New York University     198      100    82
# #3                  Smith  New York University     168       85    87
# #4                   John  Columbia University     188       70    65
# #5                   Kara  Columbia University     201       82    78
# #6                  Daisy  Columbia University     172       91    80
# #7                   Jack  New York University     174       77    50
#
#                     Biology  Finance Coding  Total Result
# Application Number
# #2                       78       88    NaN    348   Pass
# #3                       90       75    c++    337   Pass
# #4                       95       92   java    322   Fail
# #5                       88       84    NaN    332   Pass
# #6                       76       80    NaN    327   Fail
# #7                       85      100      r    312   Fail

# %%
df[filt].index
# Out:
# Index(['#2', '#3', '#4', '#5', '#6', '#7'], dtype='object', name='Application Number')

# %%
df.drop(index=df[filt].index)
# Out:
#                      Name               School  Height  English  Math  \
# Application Number
# #1                    Ian  Columbia University     178       90   100
# #8                  Poppy  Columbia University     180       80    90
#
#                     Biology  Finance  Coding  Total Result
# Application Number
# #1                       88       95  python    373   Pass
# #8                       70       89  python    329   Fail

# %% [markdown]
# ## Adding rows

# %%
df.loc['#9'] = ['Coco', 'New York University', 170, 95, 80, 75, 84, 'r', 334, 'Pass'] # New row
df
# Out:
#                      Name               School  Height  English  Math  \
# Application Number
# #1                    Ian  Columbia University     178       90   100
# #2                  Jason  New York University     198      100    82
# #3                  Smith  New York University     168       85    87
# #4                   John  Columbia University     188       70    65
# #5                   Kara  Columbia University     201       82    78
# #6                  Daisy  Columbia University     172       91    80
# #7                   Jack  New York University     174       77    50
# #8                  Poppy  Columbia University     180       80    90
# #9                   Coco  New York University     170       95    80
#
#                     Biology  Finance  Coding  Total Result
# Application Number
# #1                       88       95  python    373   Pass
# #2                       78       88     NaN    348   Pass
# ...

# %% [markdown]
# ## Cell correction

# %%
df.loc['#5', 'Coding'] = 'SAS'
df
# Out:
#                      Name               School  Height  English  Math  \
# Application Number
# #1                    Ian  Columbia University     178       90   100
# #2                  Jason  New York University     198      100    82
# #3                  Smith  New York University     168       85    87
# #4                   John  Columbia University     188       70    65
# #5                   Kara  Columbia University     201       82    78
# #6                  Daisy  Columbia University     172       91    80
# #7                   Jack  New York University     174       77    50
# #8                  Poppy  Columbia University     180       80    90
# #9                   Coco  New York University     170       95    80
#
#                     Biology  Finance  Coding  Total Result
# Application Number
# #1                       88       95  python    373   Pass
# #2                       78       88     NaN    348   Pass
# ...

# %%
df.loc['#6', ['School', 'Coding']] = ['New York University', 'python']
df
# Out:
#                      Name               School  Height  English  Math  \
# Application Number
# #1                    Ian  Columbia University     178       90   100
# #2                  Jason  New York University     198      100    82
# #3                  Smith  New York University     168       85    87
# #4                   John  Columbia University     188       70    65
# #5                   Kara  Columbia University     201       82    78
# #6                  Daisy  New York University     172       91    80
# #7                   Jack  New York University     174       77    50
# #8                  Poppy  Columbia University     180       80    90
# #9                   Coco  New York University     170       95    80
#
#                     Biology  Finance  Coding  Total Result
# Application Number
# #1                       88       95  python    373   Pass
# #2                       78       88     NaN    348   Pass
# ...

# %% [markdown]
# ## Changing column order

# %%
cols = list(df.columns)
cols
# Out:
# ['Name',
#  'School',
#  'Height',
#  'English',
#  'Math',
#  'Biology',
#  'Finance',
#  'Coding',
#  'Total',
#  'Result']

# %%
df = df[[cols[-1]] + cols[0:-1]]
df
# Out:
#                    Result   Name               School  Height  English  Math  \
# Application Number
# #1                   Pass    Ian  Columbia University     178       90   100
# #2                   Pass  Jason  New York University     198      100    82
# #3                   Pass  Smith  New York University     168       85    87
# #4                   Fail   John  Columbia University     188       70    65
# #5                   Pass   Kara  Columbia University     201       82    78
# #6                   Fail  Daisy  New York University     172       91    80
# #7                   Fail   Jack  New York University     174       77    50
# #8                   Fail  Poppy  Columbia University     180       80    90
# #9                   Pass   Coco  New York University     170       95    80
#
#                     Biology  Finance  Coding  Total
# Application Number
# #1                       88       95  python    373
# #2                       78       88     NaN    348
# ...

# %% [markdown]
# ## Change column name

# %%
df.columns
# Out:
# Index(['Result', 'Name', 'School', 'Height', 'English', 'Math', 'Biology',
#        'Finance', 'Coding', 'Total'],
#       dtype='object')

# %%
df = df[['Name', 'Coding']]
df
# Out:
#                      Name  Coding
# Application Number
# #1                    Ian  python
# #2                  Jason     NaN
# #3                  Smith     c++
# #4                   John    java
# #5                   Kara     SAS
# #6                  Daisy  python
# #7                   Jack       r
# #8                  Poppy  python
# #9                   Coco       r
